# %%
# Syntax Error - invalid coding
x = 2 
y = 4

# %%
# Runtume Error  - valid code, impossible to compute
y = x / 2

# %%
# Value Errors - a value given cannot be used for operation
z = int("78")

# %%
# Name Error - variable has been called without being defined
q = 57
y = q * 2

# %%
# Type Error - invalid data type(s) used
x = 1
y = 2.0
z = x + y

# %%
# Indentation Error - indentation occurs when it is not expected
x = 2
y = 3
z = x + y

# %%
# User error - program not mathematically or logically sound
name = "Julie"
age = 42
no_years = float(7)
age_future = age + no_years

print("Hello, \nmy name is", name, "and \nmy age is", age, "\n and in", no_years, "years, I will be", age_future)
# Out:
# Hello,
# my name is Julie and
# my age is 42
#  and in 7.0 years, I will be 49.0
