# %%
# This is a comment
# x is the variable
# = assigns a value to a variable
# 2 + 4 is the assignment
x = 2 + 4
x_2 = 3 + 3

print("This section defines x = ", x)
# Out:
# This section defines x =  6

# %%
print(x) # Show value of x
y = x + x # Complete operation to calculate y
print(y)  # Show value of y
# Out:
# 6
# 12

# %%
print(x, end = ' ') # Print x without a newline
print(y) # Print y
# Out:
# 6 12

# %%
# Printing strings
name = "Frank"
age = 27
print("My name is", name, "and my age is", age)
# Out:
# My name is Frank and my age is 27

# %%
# Printing strings with new lines
print("Hello, \nmy name is", name, "and \nmy age is", age)
# Out:
# Hello,
# my name is Frank and
# my age is 27
